# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\vitor\OneDrive\VITOR\Python\Modulo11 - Analise e visualizacao de dados\Dados\dadosgovbr---2014.csv",sep = ';', encoding="latin-1")

# %%
df.head()
# Out:
#                                               Gestor   Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Não identificado     SE
# 1  Instituto Estadual de Proteção e Defesa do Con...  Não identificado     SE
# 2                  Secretaria Nacional do Consumidor  Não identificado     SE
# 3  Instituto de Promoção e Defesa do Cidadão e Co...  Não identificado     NE
# 4  Secretaria de Desenvolvimento Social e Direito...  Não identificado     NE
#
#    UF         Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  RJ       Itaboraí    M  entre 31 a 40 anos          2014             6
# 1  ES          Serra    F  entre 31 a 40 anos          2014             6
# 2  RJ  Volta Redonda    M  entre 31 a 40 anos          2014             6
# 3  MA       São Luís    F  entre 31 a 40 anos          2014             5
# 4  PE         Recife    M  entre 21 a 30 anos          2014             6
#
# ...

# %%
df.Região.value_counts()
# Out:
# SE    22056
# S      9539
# NE     7000
# CO     4234
# N      1158
# Name: Região, dtype: int64

# %% [markdown]
# ### ANALISE DE DADOS
#
# # 1)

# %%
print(f'Total de reclamacoes: {df.Total.count()}')
# Out:
# Total de reclamacoes: 43987

# %% [markdown]
# # 2)

# %%
print(f"Tempo médio : {df['Tempo Resposta'].mean():.2f}")
# Out:
# Tempo médio : 6.67

# %%
print(f" Tempo Maximo:  {df['Tempo Resposta'].max()}")
# Out:
#  Tempo Maximo:  13.0

# %%
print(f"Tempo Minimo:  {df['Tempo Resposta'].min()}")
# Out:
# Tempo Minimo:  0.0

# %% [markdown]
# # 3)

# %%
print(f"Nota Media: {df['Nota do Consumidor'].mean():.2f}" )
# Out:
# Nota Media: 3.01

# %%
print(f"Nota Maxima: {df['Nota do Consumidor'].max()}")
# Out:
# Nota Maxima: 5.0

# %%
print(f"Nota Minima: {df['Nota do Consumidor'].min()}")
# Out:
# Nota Minima: 1.0

# %% [markdown]
# # 4)
# Analisando, na minha opiniao, quanto maior o tempo de resposta, menor é a nota do consumidor.

# %%
df[['Tempo Resposta', 'Nota do Consumidor']]
# Out:
#        Tempo Resposta  Nota do Consumidor
# 0                 5.0                 NaN
# 1                 6.0                 1.0
# 2                 5.0                 5.0
# 3                 0.0                 5.0
# 4                 1.0                 NaN
# ...               ...                 ...
# 43982            10.0                 NaN
# 43983             5.0                 1.0
# 43984             3.0                 1.0
# 43985             8.0                 NaN
# 43986             0.0                 3.0
#
# [43987 rows x 2 columns]

# %% [markdown]
# # 5)

# %%
print(" Frequencia de Reclamacao por sexo:")
df.Sexo.value_counts()
# Out:
#  Frequencia de Reclamacao por sexo:
# M    27895
# F    16092
# Name: Sexo, dtype: int64

# %% [markdown]
# # 6)

# %%
print(" Frequencia de Reclamacao por estado:")
df.Região.value_counts()
# Out:
#  Frequencia de Reclamacao por estado:
# SE    22056
# S      9539
# NE     7000
# CO     4234
# N      1158
# Name: Região, dtype: int64

# %% [markdown]
# # 7)

# %%
df['Respondida'].value_counts(normalize=True)*100
# Out:
# S    95.394094
# N     4.605906
# Name: Respondida, dtype: float64

# %% [markdown]
# ###  VISUALIZACAO DE DADOS

# %% [markdown]
# # 5) A

# %%
import matplotlib.pyplot as plt

# %%
df.Sexo.value_counts()
# Out:
# M    27895
# F    16092
# Name: Sexo, dtype: int64

# %%
plt.figure(figsize=(10,5))
sexo = df.Sexo.value_counts().plot.bar(color=['blue', 'red'])
sexo.bar_label(sexo.containers[0], label_type='edge', fontsize=15)
plt.title('Frequência de reclamações por sexo', fontdict = {'fontsize' : 25, 'fontweight':'bold'})
plt.ylabel('Reclamações')
plt.xlabel('Sexo')
plt.legend(handles=[female, male], loc='best')
plt.show()

# %% [markdown]
# # 5) B

# %%
df.Região.value_counts()
# Out:
# SE    22056
# S      9539
# NE     7000
# CO     4234
# N      1158
# Name: Região, dtype: int64

# %%
plt.figure(figsize=(10,5))
estado = df.UF.value_counts().plot.bar(color=['green', 'red'])
plt.title('Frequência de reclamações por estado', fontdict = {'fontsize' : 25, 'fontweight':'bold'})
plt.ylabel('Reclamações')
plt.xlabel('Estados')
plt.show()

# %% [markdown]
# # 5) C

# %%
plt.figure(figsize=(10,5))
reclamacao = df.Respondida.value_counts().plot.bar(color=['blue', 'red'])
reclamacao.bar_label(reclamacao.containers[0], label_type='edge', fontsize=15)
plt.title('Frequência de Reclamações', fontdict = {'fontsize' : 20, 'fontweight':'bold'})
plt.ylabel('Reclamações')
plt.xlabel('Frequencia Respondida')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # 6)

# %%
resposta1= (df['Respondida'].value_counts()[0] * 100) / df.Total.count()
resposta2 = (df['Respondida'].value_counts()[1] * 100) / df.Total.count()
labels = df.Respondida.unique()
plt.figure(figsize=(10,5))
plt.title('Porcentagem de Reclamações', fontdict = {'fontsize' : 20, 'fontweight':'bold'})
plt.pie(df['Respondida'].value_counts(), labels=labels ,shadow = True, startangle=5 , explode=explode, wedgeprops = {"edgecolor": 'black'} ,autopct='%.2f%%')
plt.show()

# %%
pip install seaborn
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\vitor\PycharmProjects\mentorama\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='Tempo Resposta', hue='Nota do Consumidor', stat='count', multiple='dodge',shrink=0.8, palette="deep")
plt.title("Nota do Consumidor e Tempo para Resposta",{'fontsize' : 15, 'fontweight':'bold'})
plt.ylabel('Tempo Resposta')
plt.xlabel('Nota do Consumidor')
plt.show()
